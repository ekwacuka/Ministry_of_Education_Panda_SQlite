# %%
import pandas as pd
import sqlite3 as sql
import webbrowser
import csv

## Load a comma-separated values (csv) file into DataFrame(df)

df = pd.read_csv(r"C:\Users\Emily Kimani\Desktop\Adv_Python\Pandas\teacher_by_status_and_county_for_secondary.csv")

## Displays the DataFrame(df) - the 1st five rows and the last 5 rows

display(df)
# Out:
#               County School_Type Employment_Body  No_of_Teachers  \
# 0    Baringo             Public          TSC                1172
# 1    Bomet               Public          TSC                1379
# 2    Bungoma             Public          TSC                2946
# 3    Busia               Public          TSC                1182
# 4    Elgeyo Marakwet     Public          TSC                1087
# ..               ...         ...             ...             ...
# 187  Uasin Gishu         Private         TSC                   0
# 188  Vihiga              Private         TSC                   0
# 189  Wajir               Private         TSC                   0
# 190  West Pokot          Private         TSC                   0
# 191  Kenya               Private         TSC                   0
#
#           County (centroid)                    Year
# 0     (0.669252, 35.946465)  12/31/2014 12:00:00 AM
# 1    (-0.726295, 35.298598)  12/31/2014 12:00:00 AM
# ...

# %%
## Prints the Total number of rows in this DataFrame(df)

df.count()
# Out:
# County               192
# School_Type          192
# Employment_Body      192
# No_of_Teachers       192
# County (centroid)    188
# Year                 192
# dtype: int64

# %%
## Prints the column names in Pandas DataFrame(df)

df.columns
# Out:
# Index(['County', 'School_Type', 'Employment_Body', 'No_of_Teachers',
#        'County (centroid)', 'Year'],
#       dtype='object')

# %%
## Extracts Column Names as List in Pandas Dataframe(df)

df.columns.tolist()
# Out:
# ['County',
#  'School_Type',
#  'Employment_Body',
#  'No_of_Teachers',
#  'County (centroid)',
#  'Year']

# %%
## It drops/deletes the County (Centroid) column from the DataFrame(df)

df.drop('County (centroid)', inplace=True, axis=1) 

display(df)
# Out:
#               County School_Type Employment_Body  No_of_Teachers  \
# 0    Baringo             Public          TSC                1172
# 1    Bomet               Public          TSC                1379
# 2    Bungoma             Public          TSC                2946
# 3    Busia               Public          TSC                1182
# 4    Elgeyo Marakwet     Public          TSC                1087
# ..               ...         ...             ...             ...
# 187  Uasin Gishu         Private         TSC                   0
# 188  Vihiga              Private         TSC                   0
# 189  Wajir               Private         TSC                   0
# 190  West Pokot          Private         TSC                   0
# 191  Kenya               Private         TSC                   0
#
#                        Year
# 0    12/31/2014 12:00:00 AM
# 1    12/31/2014 12:00:00 AM
# 2    12/31/2014 12:00:00 AM
# 3    12/31/2014 12:00:00 AM
# 4    12/31/2014 12:00:00 AM
# ...

# %%
import sqlite3

## Creates a database connection SQLite and creates a database.

conn = sqlite3.connect('MINISTRYOFEDUCATION.db')

## Create a Cursor Object 

cursor = conn.cursor()

print("\t MINISTRYOFEDUCATION Database created \n")

## Creates Teachers table

cursor.execute(''' CREATE TABLE IF NOT EXISTS teacher (
        COUNTY VARCHAR(100),
        SCHOOL_TYPE VARCHAR(100),
        EMPLOYMENT_BODY VARCHAR(100),
        NO_OF_TEACHERS INT(15),
        YEAR DATETIME);''')

print("\t TEACHER TABLE STRUCTURE \n")

conn.commit()
# Out:
# 	 MINISTRYOFEDUCATION Database created
#
# 	 TEACHER TABLE STRUCTURE

# %%
## writes records stored in a DataFrame to a SQLite database (defined in conn)

df.to_sql('teacher', conn, if_exists='replace', index=False)
# Out:
# C:\Users\Emily Kimani\anaconda3\lib\site-packages\pandas\core\generic.py:2605: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
html = r'<link rel="stylesheet" type="text/css" media="screen" href="C:\Users\Emily Kimani\Desktop\Adv_Python\Pandas\Table1.css" />' + '\n'

html += df.to_html()

with open('MinistryOfHigherEducation.html','w') as f:
    f.write(html)
    f.close()
    pass

# Open file in browser
webbrowser.open_new_tab('MinistryOfHigherEducation.html')
# Out:
# True
